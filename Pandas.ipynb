# %% [markdown]
# # Pandas
# <font size=5>uses series(1D) and data frames(2D data)
#
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.</font>

# %% [markdown]
# External file data can be retrieved in series and data frames (format - xlms,csv,txt,database)

# %%
import pandas as pd

# %%
text_series = pd.Series(['Python','Maths','ML','DL','Statistics'])
text_series
# Out:
# 0        Python
# 1         Maths
# 2            ML
# 3            DL
# 4    Statistics
# dtype: object

# %%
text_series[1]
# Out:
# 'Maths'

# %%
text_series[1:4]
# Out:
# 1    Maths
# 2       ML
# 3       DL
# dtype: object

# %% [markdown]
# # To change indexing of lists.

# %% [markdown]
# <font size=5>While we can change index, we can also use the old indexing.</font>

# %%
text_series = pd.Series(['Python','Maths','ML','DL','Statistics'], index = [1,2,3,4,5])
text_series
# Out:
# 1        Python
# 2         Maths
# 3            ML
# 4            DL
# 5    Statistics
# dtype: object

# %% [markdown]
# # Dataframe

# %% [markdown]
# <font size = 6> structred representation of data</font>

# %%
market = pd.read_csv('market_fact.csv')

# %%
market
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %% [markdown]
# <font size = 6> Whatever changes done here to the file will not be done to original file.</font>

# %% [markdown]
# <font size = 6>Head shows or limits first 5 rows by default.</font>

# %%
market.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market.head(10)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0              23   -30.51           3.60                 0.56
# 1              13     4.56           0.93                 0.54
# 2              26  1148.90           2.50                 0.59
# ...

# %% [markdown]
# <font size = 6>Tail used to get end data of table or file.</font>

# %%
market.tail()
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %% [markdown]
# <font size = 6>To get info about the table</font>

# %%
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %% [markdown]
# <font size = 6>dtype represnts string values in pandas</font>

# %%
market.shape
# Out:
# (8399, 10)

# %%
market.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
market.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %% [markdown]
# # What Can Pandas Do?

# %% [markdown]
# <font size = 5>Pandas gives you answers about the data. Like:
#
# Is there a correlation between two or more columns?
#
# What is average value?
#
# Max value?
#
# Min value?</font>

# %%
market.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market.sort_values(by='Profit').head(20)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 6952  Ord_5452  Prod_17  SHP_7621  Cust_1796  18888.00      0.09
# 4772  Ord_5047  Prod_17  SHP_7043  Cust_1714  19707.20      0.04
# 84    Ord_5232  Prod_17  SHP_7306  Cust_1758  21366.51      0.00
# 5454  Ord_3903  Prod_14  SHP_5417  Cust_1334   3457.99      0.05
# 5968  Ord_3073  Prod_14  SHP_4267  Cust_1142   3550.28      0.06
# 4291   Ord_138  Prod_10   SHP_185    Cust_92  26133.39      0.04
# 6885  Ord_4972  Prod_17  SHP_6941  Cust_1697  19014.24      0.06
# 4259  Ord_1980  Prod_10  SHP_2706   Cust_924  24391.16      0.04
# 1926  Ord_4566  Prod_14  SHP_6354  Cust_1515  13698.96      0.05
# 3586  Ord_3351  Prod_17  SHP_6380  Cust_1562   9172.32      0.06
# 4795  Ord_4903  Prod_17  SHP_6838  Cust_1681  10380.34      0.05
# 4295  Ord_4704  Prod_17  SHP_6564  Cust_1633   3360.30      0.05
# 7758  Ord_4434  Prod_17  SHP_6179  Cust_1490   3501.79      0.01
# ...

# %% [markdown]
# <font size = 5>by default it will return ascending order.</font>

# %% [markdown]
# <font size = 5>To do it in descending order we do:</font>

# %%
market.sort_values(by='Profit', ascending=False).head(20)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 6765  Ord_5186  Prod_17  SHP_7247  Cust_1763  26095.13      0.03
# 6660  Ord_5425  Prod_14  SHP_7580  Cust_1799  27720.98      0.07
# 5042  Ord_2425  Prod_14  SHP_3329   Cust_934  27820.34      0.08
# 6037  Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 4124  Ord_2345   Prod_3  SHP_3218   Cust_937  25409.63      0.02
# 3241   Ord_118   Prod_3   SHP_161    Cust_63  23792.93      0.00
# 5971  Ord_3059  Prod_17  SHP_4249  Cust_1143  21921.28      0.04
# 6797  Ord_1265  Prod_14  SHP_1749   Cust_466  24051.49      0.07
# 197   Ord_2753   Prod_3  SHP_3778   Cust_997  23106.46      0.08
# ...

# %% [markdown]
# <font size = 6>To sort multiple values we use list</font>

# %%
market.sort_values(by=['Profit','Sales'], ascending=False).head(20)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 6765  Ord_5186  Prod_17  SHP_7247  Cust_1763  26095.13      0.03
# 6660  Ord_5425  Prod_14  SHP_7580  Cust_1799  27720.98      0.07
# 5042  Ord_2425  Prod_14  SHP_3329   Cust_934  27820.34      0.08
# 6037  Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 4124  Ord_2345   Prod_3  SHP_3218   Cust_937  25409.63      0.02
# 3241   Ord_118   Prod_3   SHP_161    Cust_63  23792.93      0.00
# 5971  Ord_3059  Prod_17  SHP_4249  Cust_1143  21921.28      0.04
# 6797  Ord_1265  Prod_14  SHP_1749   Cust_466  24051.49      0.07
# 197   Ord_2753   Prod_3  SHP_3778   Cust_997  23106.46      0.08
# ...

# %% [markdown]
# <font size=6>Indexing and Slicing</font>

# %%
market.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %% [markdown]
# <font size=6>To get values from and to </font>

# %%
market[10:51]
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11  Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12  Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# 13  Ord_2207  Prod_11  SHP_3093   Cust_839   3364.2480      0.10
# 14  Ord_2207  Prod_10  SHP_3006   Cust_839   1410.9300      0.08
# 15  Ord_2280   Prod_5  SHP_3114   Cust_839    460.6900      0.06
# 16  Ord_2282   Prod_9  SHP_3122   Cust_839    443.4600      0.06
# 17  Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02
# 18  Ord_4427   Prod_6  SHP_6171  Cust_1521    283.1300      0.08
# 19   Ord_996  Prod_13  SHP_1378   Cust_371     41.9700      0.05
# 20   Ord_996  Prod_13  SHP_1378   Cust_371     57.1700      0.08
# 21   Ord_996   Prod_6  SHP_1378   Cust_371     81.2500      0.01
# 22   Ord_996   Prod_5  SHP_1377   Cust_371   3202.2500      0.09
# ...

# %% [markdown]
# <font size=6>To select a column</font>

# %%
market['Profit']
# Out:
# 0        -30.51
# 1          4.56
# 2       1148.90
# 3        729.34
# 4       1219.87
#          ...
# 8394     374.63
# 8395     -74.03
# 8396     -70.85
# 8397     565.34
# 8398     131.39
# Name: Profit, Length: 8399, dtype: float64

# %% [markdown]
# <font size=6>To select multiple columns</font>

# %%
market[['Profit','Sales']]
# Out:
#        Profit      Sales
# 0      -30.51   136.8100
# 1        4.56    42.2700
# 2     1148.90  4701.6900
# 3      729.34  2337.8900
# 4     1219.87  4233.1500
# ...       ...        ...
# 8394   374.63  2841.4395
# 8395   -74.03   127.1600
# 8396   -70.85   243.0500
# 8397   565.34  3872.8700
# 8398   131.39   603.6900
#
# [8399 rows x 2 columns]

# %% [markdown]
# <font size=6>We can't select column and specific value with indexing and slicing</font>

# %%
market[1:4,['Profit','Sales']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(1, 4, None), ['Profit', 'Sales'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /Users/ritikramesh/Documents/Python/PYINT/CLASSES/Pandas Hands_on/Pandas.ipynb Cell 44 in <cell line: 1>()
# ...

# %% [markdown]
# <font size=6>To overcome this we use .loc</font>

# %%
market.loc[1:4,['Profit','Sales']]
# Out:
#     Profit    Sales
# 1     4.56    42.27
# 2  1148.90  4701.69
# 3   729.34  2337.89
# 4  1219.87  4233.15

# %% [markdown]
# ## loc and iloc
#
# <font size=5>Select rows
#
# Select cols
#
# Select particular rows and cols</font>

# %% [markdown]
# <font size=6>iloc - index location</font><br>
# <font size=5>we use index of col as well</font>

# %%
market.iloc[2:6,2:6]
# Out:
#     Ship_id    Cust_id    Sales  Discount
# 2  SHP_7610  Cust_1818  4701.69      0.00
# 3  SHP_7625  Cust_1818  2337.89      0.09
# 4  SHP_7664  Cust_1818  4233.15      0.08
# 5  SHP_7608  Cust_1818   164.02      0.03

# %%
market.iloc[2:9,2:5]
# Out:
#     Ship_id    Cust_id      Sales
# 2  SHP_7610  Cust_1818  4701.6900
# 3  SHP_7625  Cust_1818  2337.8900
# 4  SHP_7664  Cust_1818  4233.1500
# 5  SHP_7608  Cust_1818   164.0200
# 6    SHP_41    Cust_26    14.7600
# 7  SHP_6593  Cust_1641  3410.1575
# 8  SHP_6593  Cust_1641   162.0000

# %%
market.iloc[[2,4,7],[2,4,5]]
# Out:
#     Ship_id      Sales  Discount
# 2  SHP_7610  4701.6900      0.00
# 4  SHP_7664  4233.1500      0.08
# 7  SHP_6593  3410.1575      0.10

# %%
market.iloc[2,4]
# Out:
# 4701.69

# %%
market.iloc[2:17,[3,4,5,7]]
# Out:
#       Cust_id      Sales  Discount   Profit
# 2   Cust_1818  4701.6900      0.00  1148.90
# 3   Cust_1818  2337.8900      0.09   729.34
# 4   Cust_1818  4233.1500      0.08  1219.87
# 5   Cust_1818   164.0200      0.03   -47.64
# 6     Cust_26    14.7600      0.01     1.32
# 7   Cust_1641  3410.1575      0.10  1137.91
# 8   Cust_1641   162.0000      0.01    45.84
# 9   Cust_1641    57.2200      0.07   -27.72
# 10  Cust_1641  4072.0100      0.01  1675.98
# 11   Cust_708   465.9000      0.05    79.34
# 12  Cust_1088   305.0500      0.04    23.12
# 13   Cust_839  3364.2480      0.10  -693.23
# 14   Cust_839  1410.9300      0.08  -317.48
# 15   Cust_839   460.6900      0.06  -103.48
# 16   Cust_839   443.4600      0.06   193.12

# %% [markdown]
# <font size=6>loc - labeled location</font>

# %%
market.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market.loc[2:6, 'Ship_id':'Discount']
# Out:
#     Ship_id    Cust_id    Sales  Discount
# 2  SHP_7610  Cust_1818  4701.69      0.00
# 3  SHP_7625  Cust_1818  2337.89      0.09
# 4  SHP_7664  Cust_1818  4233.15      0.08
# 5  SHP_7608  Cust_1818   164.02      0.03
# 6    SHP_41    Cust_26    14.76      0.01

# %%
market.loc[2:5,['Ship_id','Sales','Profit']]
# Out:
#     Ship_id    Sales   Profit
# 2  SHP_7610  4701.69  1148.90
# 3  SHP_7625  2337.89   729.34
# 4  SHP_7664  4233.15  1219.87
# 5  SHP_7608   164.02   -47.64

# %% [markdown]
# <font size=6>To change the index of data</font>

# %%
market = market.set_index('Cust_id')

# %%
market.head()
# Out:
#              Ord_id  Prod_id   Ship_id    Sales  Discount  Order_Quantity  \
# Cust_id
# Cust_1818  Ord_5446  Prod_16  SHP_7609   136.81      0.01              23
# Cust_1818  Ord_5406  Prod_13  SHP_7549    42.27      0.01              13
# Cust_1818  Ord_5446   Prod_4  SHP_7610  4701.69      0.00              26
# Cust_1818  Ord_5456   Prod_6  SHP_7625  2337.89      0.09              43
# Cust_1818  Ord_5485  Prod_17  SHP_7664  4233.15      0.08              35
#
#             Profit  Shipping_Cost  Product_Base_Margin
# Cust_id
# Cust_1818   -30.51           3.60                 0.56
# Cust_1818     4.56           0.93                 0.54
# Cust_1818  1148.90           2.50                 0.59
# Cust_1818   729.34          14.30                 0.37
# Cust_1818  1219.87          26.30                 0.38

# %% [markdown]
# <font size=6>index number should not have name</font>

# %%
market.index.name = None

# %%
market.head()
# Out:
#              Ord_id  Prod_id   Ship_id    Sales  Discount  Order_Quantity  \
# Cust_1818  Ord_5446  Prod_16  SHP_7609   136.81      0.01              23
# Cust_1818  Ord_5406  Prod_13  SHP_7549    42.27      0.01              13
# Cust_1818  Ord_5446   Prod_4  SHP_7610  4701.69      0.00              26
# Cust_1818  Ord_5456   Prod_6  SHP_7625  2337.89      0.09              43
# Cust_1818  Ord_5485  Prod_17  SHP_7664  4233.15      0.08              35
#
#             Profit  Shipping_Cost  Product_Base_Margin
# Cust_1818   -30.51           3.60                 0.56
# Cust_1818     4.56           0.93                 0.54
# Cust_1818  1148.90           2.50                 0.59
# Cust_1818   729.34          14.30                 0.37
# Cust_1818  1219.87          26.30                 0.38

# %%
market.loc['Cust_1818']
# Out:
#              Ord_id  Prod_id   Ship_id    Sales  Discount  Order_Quantity  \
# Cust_1818  Ord_5446  Prod_16  SHP_7609   136.81      0.01              23
# Cust_1818  Ord_5406  Prod_13  SHP_7549    42.27      0.01              13
# Cust_1818  Ord_5446   Prod_4  SHP_7610  4701.69      0.00              26
# Cust_1818  Ord_5456   Prod_6  SHP_7625  2337.89      0.09              43
# Cust_1818  Ord_5485  Prod_17  SHP_7664  4233.15      0.08              35
# Cust_1818  Ord_5446   Prod_6  SHP_7608   164.02      0.03              23
#
#             Profit  Shipping_Cost  Product_Base_Margin
# Cust_1818   -30.51           3.60                 0.56
# Cust_1818     4.56           0.93                 0.54
# Cust_1818  1148.90           2.50                 0.59
# Cust_1818   729.34          14.30                 0.37
# Cust_1818  1219.87          26.30                 0.38
# Cust_1818   -47.64           6.15                 0.37

# %%
market.reset_index()
# Out:
#           index    Ord_id  Prod_id   Ship_id      Sales  Discount  \
# 0     Cust_1818  Ord_5446  Prod_16  SHP_7609   136.8100      0.01
# 1     Cust_1818  Ord_5406  Prod_13  SHP_7549    42.2700      0.01
# 2     Cust_1818  Ord_5446   Prod_4  SHP_7610  4701.6900      0.00
# 3     Cust_1818  Ord_5456   Prod_6  SHP_7625  2337.8900      0.09
# 4     Cust_1818  Ord_5485  Prod_17  SHP_7664  4233.1500      0.08
# ...         ...       ...      ...       ...        ...       ...
# 8394  Cust_1798  Ord_5353   Prod_4  SHP_7479  2841.4395      0.08
# 8395  Cust_1798  Ord_5411   Prod_6  SHP_7555   127.1600      0.10
# 8396  Cust_1798  Ord_5388   Prod_6  SHP_7524   243.0500      0.02
# 8397  Cust_1798  Ord_5348  Prod_15  SHP_7469  3872.8700      0.03
# 8398  Cust_1798  Ord_5459   Prod_6  SHP_7628   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market = market.reset_index(drop=False)

# %%
market.head()
# Out:
#        index    Ord_id  Prod_id   Ship_id    Sales  Discount  Order_Quantity  \
# 0  Cust_1818  Ord_5446  Prod_16  SHP_7609   136.81      0.01              23
# 1  Cust_1818  Ord_5406  Prod_13  SHP_7549    42.27      0.01              13
# 2  Cust_1818  Ord_5446   Prod_4  SHP_7610  4701.69      0.00              26
# 3  Cust_1818  Ord_5456   Prod_6  SHP_7625  2337.89      0.09              43
# 4  Cust_1818  Ord_5485  Prod_17  SHP_7664  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %% [markdown]
# <font size=6>Merging the data</font>

# %% [markdown]
# <font size=6>To work on multiple files we will <br>
# first merge data<br>
# then, read that data file</font>

# %% [markdown]
# <font size=6>Merging is done on common col.</font>

# %% [markdown]
# <font size=6>four types of merging<br>
# Inner join - only matching keys are going to be merged other will be left out or not considered or ignored<br>
# Outer join - all the matching values will be merged with all the non matching as well<br>
# Left join - all the values from left table will be merged<br>
# Right join - all the values from right table will be merged</font>

# %%
market = pd.read_csv('market_fact.csv')
customer = pd.read_csv('cust_dimen.csv')
product = pd.read_csv('prod_dimen.csv')

# %%
customer.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
product.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
newdf = pd.merge(market,customer, how= 'inner',on= 'Cust_id')
newdf.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  Customer_Name Province Region  \
# 0   -30.51           3.60                 0.56  AARON BERGMAN  ALBERTA   WEST
# 1     4.56           0.93                 0.54  AARON BERGMAN  ALBERTA   WEST
# 2  1148.90           2.50                 0.59  AARON BERGMAN  ALBERTA   WEST
# 3   729.34          14.30                 0.37  AARON BERGMAN  ALBERTA   WEST
# 4  1219.87          26.30                 0.38  AARON BERGMAN  ALBERTA   WEST
#
#   Customer_Segment
# ...

# %% [markdown]
# <font size=6>market : 'Cust_id'<br>
# customer : 'Id'<br>
# pd.merge(market, customer, how= 'inner', left_on= 'Cust_id, right_on= 'Id')</font>

# %%
masterdf = pd.merge(newdf,product, how= 'inner', on= 'Prod_id')
masterdf.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_2978  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27
# 2  Ord_5484  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35
# 3  Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34
# 4  Ord_4143  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24
#
#    Profit  Shipping_Cost  Product_Base_Margin        Customer_Name  \
# 0  -30.51           3.60                 0.56        AARON BERGMAN
# 1   23.12           3.37                 0.57        AARON HAWKINS
# 2  -17.58           3.98                 0.56         ADRIAN SHAMI
# 3   61.57           3.14                 0.60  ALEKSANDRA GANNAWAY
# 4  -78.64           6.14                 0.59         ALLEN ARMOLD
#
#         Province    Region Customer_Segment Product_Category  \
# ...

# %% [markdown]
# <font size=6>To save merged data file.</font>

# %%
masterdf.to_csv('merged_data.csv', index= False)
